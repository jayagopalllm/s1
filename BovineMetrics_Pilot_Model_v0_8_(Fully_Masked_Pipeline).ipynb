# %% [markdown]
# <a href="https://colab.research.google.com/github/jayagopalllm/s1/blob/main/BovineMetrics_Pilot_Model_v0_8_(Fully_Masked_Pipeline).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#
# Project BovineMetrics - Pilot Model v0.8
# Google Colab Notebook
#
# This version introduces a fully masked `tf.data` pipeline using `tf.py_function`.
# This is a major architectural upgrade that allows us to apply our complex
# COCO segmentation masks inside the high-performance data pipeline. It correctly
# handles missing images and forces the model to learn from pixel data.
#

# ==============================================================================
# STEP 1: SETUP AND IMPORTS
# ==============================================================================
# !pip install tensorflow pandas scikit-learn pycocotools matplotlib

import os
import numpy as np
import pandas as pd
import cv2
from google.colab import drive
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D, concatenate, Dropout, RandomFlip, RandomRotation, RandomZoom
from pycocotools.coco import COCO
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt

print("TensorFlow Version:", tf.__version__)

# ==============================================================================
# STEP 2: MOUNT GOOGLE DRIVE AND DEFINE PATHS
# ==============================================================================
print("Mounting Google Drive...")
drive.mount('/content/drive')
print("Drive mounted successfully.")

# --- IMPORTANT: UPDATE THESE PATHS ---
BASE_DRIVE_PATH = '/content/drive/MyDrive/dataset/'
SIDE_IMAGE_DIR = os.path.join(BASE_DRIVE_PATH, 'side_view_images')
TOP_IMAGE_DIR = os.path.join(BASE_DRIVE_PATH, 'top_view_images')
SIDE_ANNOTATIONS_PATH = os.path.join(BASE_DRIVE_PATH, 'side_view_annotations.json')
TOP_ANNOTATIONS_PATH = os.path.join(BASE_DRIVE_PATH, 'top_view_annotations.json')
METADATA_CSV_PATH = os.path.join(BASE_DRIVE_PATH, 'cattle_data.csv')
# ------------------------------------

# --- Create a placeholder image for missing views ---
IMG_HEIGHT, IMG_WIDTH = 224, 224
PLACEHOLDER_PATH = os.path.join(BASE_DRIVE_PATH, "placeholder.jpg")
if not os.path.exists(PLACEHOLDER_PATH):
    placeholder_image = np.zeros((IMG_HEIGHT, IMG_WIDTH, 3), dtype="uint8")
    cv2.imwrite(PLACEHOLDER_PATH, placeholder_image)
    print("Created placeholder image for missing views.")

# ==============================================================================
# STEP 3: LOAD AND PREPROCESS THE DATA (REFACTORED for tf.data)
# ==============================================================================
print("\nLoading metadata from CSV...")
metadata_df = pd.read_csv(METADATA_CSV_PATH)
metadata_df.columns = metadata_df.columns.str.strip().str.lower()
print(f"Loaded {len(metadata_df)} records from CSV.")

print("Loading COCO annotations...")
coco_side = COCO(SIDE_ANNOTATIONS_PATH)
coco_top = COCO(TOP_ANNOTATIONS_PATH)
side_filename_to_id = {img['file_name']: img['id'] for img in coco_side.dataset['images']}
top_filename_to_id = {img['file_name']: img['id'] for img in coco_top.dataset['images']}

# --- Create a unified DataFrame with all paths and data ---
data_records = []
for _, row in metadata_df.iterrows():
    record = row.to_dict()
    # Replace missing filenames with the placeholder path
    side_fname = str(row.get('side_view_filename', ''))
    top_fname = str(row.get('top_view_filename', ''))

    record['side_view_path'] = os.path.join(SIDE_IMAGE_DIR, side_fname) if pd.notna(row.get('side_view_filename')) else PLACEHOLDER_PATH
    record['top_view_path'] = os.path.join(TOP_IMAGE_DIR, top_fname) if pd.notna(row.get('top_view_filename')) else PLACEHOLDER_PATH

    data_records.append(record)

full_df = pd.DataFrame(data_records)

# --- Preprocess Tabular Data ---
categorical_features, numerical_features = ['sex', 'breed'], ['age']
preprocessor = ColumnTransformer(transformers=[
    ('num', StandardScaler(), numerical_features),
    ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)])
processed_tabular = preprocessor.fit_transform(full_df[categorical_features + numerical_features])

# --- Normalize Weights ---
weights = full_df['weight'].values.astype(np.float32)
weight_mean, weight_std = weights.mean(), weights.std()
normalized_weights = (weights - weight_mean) / weight_std

# --- Split data before creating TensorFlow Datasets ---
train_df, val_df = train_test_split(full_df, test_size=0.2, random_state=42)

# ==============================================================================
# STEP 4: CREATE THE `tf.data` PIPELINE WITH MASKING (v0.8)
# ==============================================================================
print("\nBuilding `tf.data` input pipeline with segmentation masking...")
BATCH_SIZE = 16
AUTOTUNE = tf.data.AUTOTUNE

def apply_mask(image_path_str, coco_instance, filename_to_id_map):
    """Helper function to read an image and apply its COCO mask."""
    # Read image using OpenCV
    image = cv2.imread(image_path_str)

    # Check if image was successfully loaded
    if image is None:
        print(f"Warning: Could not load image from {image_path_str}. Returning black image.")
        return np.zeros((IMG_HEIGHT, IMG_WIDTH, 3), dtype="uint8")

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Get filename to find annotations
    filename = os.path.basename(image_path_str)
    img_id = filename_to_id_map.get(filename)

    # Create mask and apply it
    if img_id:
        mask = np.zeros(image.shape[:2], dtype="uint8")
        ann_ids = coco_instance.getAnnIds(imgIds=img_id)
        anns = coco_instance.loadAnns(ann_ids)
        for ann in anns:
            for seg in ann['segmentation']:
                poly = np.array(seg).reshape((-1, 2)).astype(np.int32)
                cv2.fillPoly(mask, [poly], 255)
        masked_image = cv2.bitwise_and(image, image, mask=mask)
        return cv2.resize(masked_image, (IMG_WIDTH, IMG_HEIGHT))
    else:
        # This handles the placeholder or images without annotations
        return cv2.resize(image, (IMG_WIDTH, IMG_HEIGHT))

def process_path(side_path, top_path):
    # Decode path tensors from TensorFlow to Python strings
    side_path_str = side_path.numpy().decode('utf-8')
    top_path_str = top_path.numpy().decode('utf-8')

    side_img = apply_mask(side_path_str, coco_side, side_filename_to_id)
    top_img = apply_mask(top_path_str, coco_top, top_filename_to_id)

    return side_img.astype(np.float32), top_img.astype(np.float32)

def configure_dataset(df, tabular_data, weights):
    dataset = tf.data.Dataset.from_tensor_slices((
        (df['side_view_path'].values, df['top_view_path'].values),
        tabular_data[df.index],
        weights[df.index]
    ))
    dataset = dataset.shuffle(buffer_size=len(df))

    # Use tf.py_function to wrap our Python masking logic
    def py_func_wrapper(paths, tab, w):
        side_img, top_img = tf.py_function(
            process_path,
            [paths[0], paths[1]],
            [tf.float32, tf.float32]
        )
        side_img.set_shape([IMG_HEIGHT, IMG_WIDTH, 3])
        top_img.set_shape([IMG_HEIGHT, IMG_WIDTH, 3])
        return {"side_view_input": side_img, "top_view_input": top_img, "tabular_input": tab}, w

    dataset = dataset.map(py_func_wrapper, num_parallel_calls=AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    return dataset

train_dataset = configure_dataset(train_df, processed_tabular, normalized_weights)
val_dataset = configure_dataset(val_df, processed_tabular, normalized_weights)

# ==============================================================================
# STEP 5: BUILD THE MULTI-VIEW MODEL WITH AUGMENTATION LAYERS (v0.8)
# ==============================================================================
print("\nBuilding Masked Multi-View model with integrated augmentation...")

data_augmentation = tf.keras.Sequential([
    RandomFlip("horizontal"),
    RandomRotation(0.1),
    RandomZoom(0.1),
], name="data_augmentation")

def create_multi_view_model(image_shape, tabular_shape):
    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=image_shape)
    base_model.trainable = False

    side_input = Input(shape=image_shape, name="side_view_input")
    augmented_side = data_augmentation(side_input)
    x = base_model(augmented_side, training=False)
    x = GlobalAveragePooling2D()(x)
    side_features = Dense(64, activation='relu')(x)

    top_input = Input(shape=image_shape, name="top_view_input")
    augmented_top = data_augmentation(top_input)
    y = base_model(augmented_top, training=False)
    y = GlobalAveragePooling2D()(y)
    top_features = Dense(64, activation='relu')(y)

    tabular_input = Input(shape=(tabular_shape,), name="tabular_input")
    z = Dense(64, activation='relu')(tabular_input)
    z = Dropout(0.3)(z)
    z = Dense(32, activation='relu')(z)
    tabular_features = z

    combined = concatenate([side_features, top_features, tabular_features])
    c = Dense(128, activation='relu')(combined)
    c = Dropout(0.5)(c)
    c = Dense(64, activation='relu')(c)
    output = Dense(1, name="output")(c)

    model = Model(inputs=[side_input, top_input, tabular_input], outputs=output)
    return model

image_shape = (IMG_HEIGHT, IMG_WIDTH, 3)
tabular_shape = processed_tabular.shape[1]
model = create_multi_view_model(image_shape, tabular_shape)

# ==============================================================================
# STEP 6: INITIAL TRAINING (HEAD ONLY)
# ==============================================================================
print("\n--- Starting Initial Training (Frozen Base Model) ---")
INITIAL_EPOCHS = 100

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='mean_squared_error', metrics=['mean_absolute_error'])

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=INITIAL_EPOCHS,
    callbacks=[EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)])

# ==============================================================================
# STEP 7: FINE-TUNING STAGE
# ==============================================================================
print("\n--- Starting Fine-Tuning Stage (Unfreezing Top Layers) ---")

base_model = model.layers[4]
base_model.trainable = True
fine_tune_at = len(base_model.layers) // 10 * 6
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
              loss='mean_squared_error', metrics=['mean_absolute_error'])
model.summary()

FINE_TUNE_EPOCHS = 50
total_epochs = history.epoch[-1] + FINE_TUNE_EPOCHS

history_fine = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=total_epochs,
    initial_epoch=history.epoch[-1],
    callbacks=[EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)])

# ==============================================================================
# STEP 8: EVALUATE THE FINAL MODEL
# ==============================================================================
print("\nEvaluating final model on validation data...")
# Create a non-shuffled validation dataset for consistent evaluation
val_dataset_no_shuffle = configure_dataset(val_df, processed_tabular, normalized_weights)
val_dataset_no_shuffle = val_dataset_no_shuffle.map(lambda x, y: (x, y))

predictions_norm = model.predict(val_dataset_no_shuffle).flatten()
val_weights_kg = val_df['weight'].values
predictions_kg = (predictions_norm * weight_std) + weight_mean
predictions_kg = predictions_kg[:len(val_weights_kg)]

final_mae = np.mean(np.abs(val_weights_kg - predictions_kg))
final_mape = np.mean(np.abs((val_weights_kg - predictions_kg) / val_weights_kg)) * 100

print("\n--- PILOT MODEL v0.8 RESULTS ---")
print(f"Final Validation Mean Absolute Error (MAE): {final_mae:.2f} kg")
print(f"Final Validation Mean Absolute Percentage Error (MAPE): {final_mape:.2f}%")
print("---------------------------------")

# ==============================================================================
# STEP 9: ERROR ANALYSIS & VISUALIZATION
# ==============================================================================
print("\nStarting error analysis...")
# Create a full, non-shuffled dataset for prediction
full_dataset_no_shuffle = configure_dataset(full_df, processed_tabular, normalized_weights)
full_dataset_no_shuffle = full_dataset_no_shuffle.map(lambda x, y: (x, y))

full_dataset_predictions_norm = model.predict(full_dataset_no_shuffle).flatten()
full_dataset_predictions_kg = (full_dataset_predictions_norm * weight_std) + weight_mean
full_dataset_predictions_kg = full_dataset_predictions_kg[:len(full_df)]

error_df = full_df.copy()
error_df['predicted_weight_kg'] = full_dataset_predictions_kg
error_df['error_kg'] = error_df['predicted_weight_kg'] - error_df['weight'] # Corrected column name to 'weight'
error_df['abs_error_kg'] = np.abs(error_df['error_kg'])
error_df_sorted = error_df.sort_values(by='abs_error_kg', ascending=False)

print("\n--- TOP 20 WORST PREDICTIONS ---")
print(error_df_sorted[['side_view_filename', 'weight', 'predicted_weight_kg', 'error_kg']].head(20)) # Corrected column name to 'weight'
print("---------------------------------")

plt.figure(figsize=(10, 10))
plt.scatter(error_df['weight'], error_df['predicted_weight_kg'], alpha=0.6, edgecolors='k') # Corrected column name to 'weight'
lims = [ np.min([error_df['weight'], error_df['predicted_weight_kg']]), # Corrected column name to 'weight'
         np.max([error_df['weight'], error_df['predicted_weight_kg']]) ] # Corrected column name to 'weight'
plt.plot(lims, lims, 'r--', alpha=0.75, zorder=0, label="Perfect Prediction")
plt.xlabel("Actual Weight (kg)")
plt.ylabel("Predicted Weight (kg)")
plt.title("Model Performance: Actual vs. Predicted Weight")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk342693526865_IMG_9194.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_31-08-2025_09-41-18_3_UK743318511537_IMG_9470_frame_00028.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487513370_IMG_9464_frame_00012.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk160487513426_IMG_9176.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111421_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-35-46_1_frame_000144 (4).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK341184404092_IMG_31-08-2025_09-31-39_4_UK341184404092_IMG_9500_frame_00176.jpg. Returning black image.
#  8/35 ━━━━━━━━━━━━━━━━━━━━ 1:14 3s/step - loss: 0.2361 - mean_absolute_error: 0.3522Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk323638302900.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_31-08-2025_09-41-18_5_UK743318511537_IMG_9470_frame_00012.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487713421_IMG_30-08-2025_10-30-12_5_UK160487713421_IMG_9499_frame_00096.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK282668404422_IMG_9501_frame_00099.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_31-08-2025_09-41-03_1_UK743318511537_IMG_9469_frame_00020.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487413432_IMG_9472_frame_00042.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK322917414290_IMG_9471_frame_00019.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK341282403511_IMG_9429.jpg. Returning black image.
#  9/35 ━━━━━━━━━━━━━━━━━━━━ 1:10 3s/step - loss: 0.2407 - mean_absolute_error: 0.3559Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk305981628482 (3).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK743318611545_IMG_9443.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk304246602409.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561 (1).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111393_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-35-00_1_frame_000024 (3).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9479_frame_00054.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk342693526865_.jpg. Returning black image.
# 10/35 ━━━━━━━━━━━━━━━━━━━━ 1:07 3s/step - loss: 0.2442 - mean_absolute_error: 0.3596Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK303777401896_.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_9470_frame_00001.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318211394-2_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-37-33_1_frame_000188 (3).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk324431406083 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK305981630351_AAX_9m19d_374.5_01-08-2025_11-45-11_5_frame_00856.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK702647105728_BRBX_18m10d_488.5_01-08-2025_11-50-04_2_frame_06784.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_31-08-2025_09-41-18_3_UK743318511537_IMG_9470_frame_00028.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK340745305684_IMG_31-08-2025_09-28-08_3_UK340745305684_IMG_9473_frame_00036.jpg. Returning black image.
# 11/35 ━━━━━━━━━━━━━━━━━━━━ 1:05 3s/step - loss: 0.2502 - mean_absolute_error: 0.3628Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK745163114285_IMG_9503_frame_00003.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318211387-2_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-36-21_1_frame_000100 (3).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_9496_frame_00077.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK742081305449_IMG_9502_frame_00269.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK742081305449_IMG_9502_frame_00268.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK162699407454_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-04-59_1_frame_000052.jpg. Returning black image.
# 12/35 ━━━━━━━━━━━━━━━━━━━━ 1:04 3s/step - loss: 0.2548 - mean_absolute_error: 0.3650Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK282668404422_IMG_9501_frame_00102.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487413432_IMG_9472_frame_00041.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK340745305684_IMG_31-08-2025_09-28-08_1_UK340745305684_IMG_9473_frame_00084.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk342693626880 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK742081305449_IMG_31-08-2025_09-36-17_5_UK742081305449_IMG_9502_frame_00124.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105420_IMG_9466_frame_00000.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475503654_IMG_31-08-2025_09-42-15_5_UK743475503654_IMG_9494_frame_00208.jpg. Returning black image.
# 13/35 ━━━━━━━━━━━━━━━━━━━━ 1:01 3s/step - loss: 0.2576 - mean_absolute_error: 0.3665Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk166530105096.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk361610701400.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK702647605810_BRBX_18m5d_432.0_01-08-2025_11-53-08_5_frame_08677.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK324431306229_IMG_9485_frame_00161.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511390_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-39-42_5_frame_000092 (3).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk305901503989_IMG_9180.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487413432_IMG_9482_frame_00293.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk342693526865_IMG_9195.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk165293705883_IMG_9212.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK341652119529_AAX_17_618.5_07-11-2025_11-10-37_5982.jpg. Returning black image.
# 14/35 ━━━━━━━━━━━━━━━━━━━━ 58s 3s/step - loss: 0.2601 - mean_absolute_error: 0.3677 Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK356379400182_IMG_9489_frame_00010.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK321708507862_IMG_9477_frame_00114.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_9496_frame_00107.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK742081305449_IMG_9502_frame_00269.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511383-3_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-38-37_1_frame_000192 (3).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk160428309449_IMG_9150.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK322963103963_IMG_31-08-2025_09-21-18_1_UK322963103963_IMG_9487_frame_00028.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK322963103963_IMG_31-08-2025_09-22-01_2_UK322963103963_IMG_9504_frame_00056.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK356379400182_IMG_31-08-2025_09-34-17_1_UK356379400182_IMG_9489_frame_00028.jpg. Returning black image.
# 15/35 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - loss: 0.2619 - mean_absolute_error: 0.3685Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK322917414290_IMG_30-08-2025_10-33-22_1_UK322917414290_IMG_9471_frame_00020.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_31-08-2025_09-34-43_1_UK356379400182_IMG_9498_frame_00016.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105406_IMG_9474_frame_00212.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487113317_IMG_30-08-2025_10-21-43_2_UK160487113317_IMG_9463_frame_00020 (3).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105420_IMG_9466_frame_00079.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105420_IMG_31-08-2025_09-25-46_1_UK323282105420_IMG_9466_frame_00079.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk341546640196_IMG_9203.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_31-08-2025_09-41-18_4_UK743318511537_IMG_9470_frame_00000.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK342693126826_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-32-49_3_frame_000088.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK162699407454_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-04-59_1_frame_000052 (4).jpg. Returning black image.
# 16/35 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - loss: 0.2632 - mean_absolute_error: 0.3690Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk324191701868_IMG_9143.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9479_frame_00053 - Copy.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk341546640196_IMG_9202.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9467_frame_00293.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475503654_IMG_31-08-2025_09-42-15_5_UK743475503654_IMG_9494_frame_00208.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487513370_IMG_9464_frame_00010.jpg. Returning black image.
# 17/35 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - loss: 0.2645 - mean_absolute_error: 0.3697Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105420_IMG_31-08-2025_09-25-15_1_UK323282105420_IMG_9465_frame_00056.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK700626703750_IMG_9166.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK162699407454_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-04-59_1_frame_000052 (3).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_9496_frame_00178.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK324431306229_IMG_31-08-2025_09-27-39_1_UK324431306229_IMG_9493_frame_00024.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK282668404422_IMG_9501_frame_00121.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK340745305684_IMG_9473_frame_00039.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487513370_IMG_30-08-2025_10-28-13_1_UK160487513370_IMG_9464_frame_00238.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK702647605810_BRBX_18m5d_432.0_01-08-2025_11-53-08_1_frame_08505.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK321708507862_IMG_9477_frame_00112.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk165293705953.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk700146104303 (2).jpg. Returning black image.
# 18/35 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - loss: 0.2652 - mean_absolute_error: 0.3701Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_31-08-2025_09-40-34_1_UK743318311549_IMG_9467_frame_00028.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487413432_IMG_30-08-2025_10-23-33_1_UK160487413432_IMG_9472_frame_00028.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9467_frame_00303.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9467_frame_00069.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487213416_IMG_9468_frame_00079.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK148708205489_AAX_15_583.0_07-11-2025_10-53-32_733.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475303645_IMG_9475_frame_00040.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111421_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-35-46_1_frame_000144 (6).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk328761501318_img_9140.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318211387_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-36-56_1_frame_000084.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475303645_IMG_9475_frame_00041.jpg. Returning black image.
# 19/35 ━━━━━━━━━━━━━━━━━━━━ 45s 3s/step - loss: 0.2673 - mean_absolute_error: 0.3711Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487613196-2_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-01-15_1_frame_000008.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487213416_IMG_9468_frame_00081.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK165293605896_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-05-23_1_frame_000080.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487413432_IMG_9482_frame_00294.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318211387_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-36-56_3_frame_000080.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487213416_IMG_9468_frame_00080.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487413432_IMG_9482_frame_00295.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475303645_IMG_9475_frame_00043.jpg. Returning black image.
# 20/35 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - loss: 0.2693 - mean_absolute_error: 0.3720Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk160487313081_IMG_9186.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105420_IMG_9465_frame_00069.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_31-08-2025_09-39-09_2_UK743318111561_IMG_9497_frame_00000.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_9496_frame_00147.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_31-08-2025_09-39-09_1_UK743318111561_IMG_9497_frame_00073.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK162699407454_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-04-59_1_frame_000052 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk305901604011_IMG_9162.jpg. Returning black image.
# 21/35 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - loss: 0.2715 - mean_absolute_error: 0.3729Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk165293705925.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK324431306229_IMG_31-08-2025_09-27-15_1_UK324431306229_IMG_9485_frame_00163.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105420_IMG_9465_frame_00071.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk165293705953 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9479_frame_00053 - Copy.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9479_frame_00052 - Copy.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318211387-2_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-36-21_1_frame_000100 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK342693126826-3_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-31-58_1_frame_000176 (5).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk323638502895 (2).jpg. Returning black image.
# 22/35 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - loss: 0.2732 - mean_absolute_error: 0.3737Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK162699407454_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-04-59_1_frame_000052.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk222254101226_IMG_9147.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk281569406389.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK165879603778_IMG_9170 (1).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475503654_IMG_9494_frame_00099.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475303645_IMG_9475_frame_00042.jpg. Returning black image.
# 23/35 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - loss: 0.2743 - mean_absolute_error: 0.3742Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk305901604011_IMG_9161.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487213416_IMG_9491_frame_00003.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK742081705446_IMG_9421.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105420_IMG_31-08-2025_09-26-02_2_UK323282105420_IMG_9484_frame_00000.jpg. Returning black image.
# 24/35 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - loss: 0.2754 - mean_absolute_error: 0.3748Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK745163114285_IMG_9503_frame_00000.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk340568302614 (3).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK322963103963_IMG_31-08-2025_09-23-01_1_UK322963103963_IMG_9506_frame_00078.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK745498404591_IMG_9426.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_9470_frame_00000.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk324431406083.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_31-08-2025_09-41-03_1_UK743318511537_IMG_9469_frame_00020.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK342693126826_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-32-49_4_frame_000080.jpg. Returning black image.
# 25/35 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - loss: 0.2764 - mean_absolute_error: 0.3753Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487113317_IMG_30-08-2025_10-21-43_2_UK160487113317_IMG_9463_frame_00020 (5).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK165879603778_IMG_9169.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_9496_frame_00178.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK322917414290_IMG_30-08-2025_10-34-49_1_UK322917414290_IMG_9481_frame_00161.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105420_IMG_9484_frame_00001.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105420_IMG_9465_frame_00070.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475503654_IMG_9494_frame_00162.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318211394-2_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-37-33_1_frame_000188 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_31-08-2025_09-40-53_1_UK743318311549_IMG_9479_frame_00028.jpg. Returning black image.
# 26/35 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - loss: 0.2772 - mean_absolute_error: 0.3757Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK745163114285_IMG_9503_frame_00001.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_31-08-2025_09-34-43_1_UK356379400182_IMG_9498_frame_00016.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111421_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-35-46_1_frame_000144 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_9470_frame_00001.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475503654_IMG_9494_frame_00209.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_9496_frame_00147.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511411 (5)_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-40-20_5_frame_000096.jpg. Returning black image.
# 27/35 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - loss: 0.2778 - mean_absolute_error: 0.3759Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK322963103963_IMG_31-08-2025_09-22-31_1_UK322963103963_IMG_9505_frame_00092.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9479_frame_00015 - Copy.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK341118503079_IMG_31-08-2025_09-28-36_1_UK341118503079_IMG_9480_frame_00080.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk304246602416 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475503654_IMG_9494_frame_00116.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511383-2_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-38-01_3_frame_000024.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK702647605810_BRBX_18m5d_432.0_01-08-2025_11-53-08_4_frame_08509.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk160487313081_IMG_9187.jpg. Returning black image.
# 28/35 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - loss: 0.2783 - mean_absolute_error: 0.3760Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK148708105404_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_12-53-43_5_frame_000128.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk745163514310_IMG_9191.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475303645_IMG_9475_frame_00043.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_9470_frame_00002.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561 (3).jpg. Returning black image.
# 29/35 ━━━━━━━━━━━━━━━━━━━━ 17s 3s/step - loss: 0.2788 - mean_absolute_error: 0.3761Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511411 (4)_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-40-20_5_frame_000096.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111421_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-35-46_1_frame_000144 (3).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105406_IMG_31-08-2025_09-24-37_2_UK323282105406_IMG_9474_frame_00215.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_31-08-2025_09-38-48_3_UK743318111561_IMG_9496_frame_00076.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511383-2_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-38-01_2_frame_000032.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK742081705446_IMG_9420.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_31-08-2025_09-39-09_1_UK743318111561_IMG_9497_frame_00073.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk164501500965_IMG_9164.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK341652119529_AAX_17_618.5_07-11-2025_11-10-37_5981.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK322963103963_IMG_31-08-2025_09-21-18_5_UK322963103963_IMG_9487_frame_00364.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111393_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-35-00_1_frame_000024 (4).jpg. Returning black image.
# 30/35 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - loss: 0.2789 - mean_absolute_error: 0.3760Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_9496_frame_00077.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK324431306229_IMG_9485_frame_00162.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_31-08-2025_09-41-18_5_UK743318511537_IMG_9470_frame_00012.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK700626703750_IMG_9167.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk341546640196_IMG_9204.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK342693126826-3_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-31-58_1_frame_000176 (3).jpg. Returning black image.
# 31/35 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - loss: 0.2794 - mean_absolute_error: 0.3760Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk345484602439.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK282668404422_IMG_30-08-2025_10-31-28_2_UK282668404422_IMG_9501_frame_00096.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475503654_IMG_9494_frame_00162.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk341546640196_IMG_9206.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487213416_IMG_9491_frame_00005.jpg. Returning black image.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.2813 - mean_absolute_error: 0.3763Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk342693626880.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK162699407454_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-04-59_1_frame_000052 (3).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK322917414290_IMG_9471_frame_00021.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk305901503989_IMG_9181.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk222254101226_IMG_9148.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475303645_IMG_9475_frame_00041.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk745163514310_IMG_9192.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK342693126826_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-32-49_1_frame_000094.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487413432_IMG_9482_frame_00292.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk160487213409.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk160487513426_IMG_9178.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475303645_IMG_9475_frame_00040.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK743318611545_IMG_9444.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK305981630351_AAX_9m19d_374.5_01-08-2025_11-45-11_4_frame_00885.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487413432_IMG_9472_frame_00044.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9467_frame_00293.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511383-3_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-38-37_1_frame_000192 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487413180_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_12-59-33_1_frame_000048.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9467_frame_00041.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK742081305449_IMG_9502_frame_00271.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK322963103963_IMG_31-08-2025_09-22-01_1_UK322963103963_IMG_9504_frame_00094.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk322936202797_IMG_9199.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475503654_IMG_9494_frame_00209.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK305981630351_AAX_9m19d_374.5_01-08-2025_11-45-11_3_frame_00887.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9479_frame_00015 - Copy.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK702647605810_BRBX_18m5d_432.0_01-08-2025_11-53-08_2_frame_08672.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk160487513426_IMG_9177.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_31-08-2025_09-38-48_2_UK743318111561_IMG_9496_frame_00178.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk165293705883_IMG_9211.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK341282603275_IMG_9154.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk323638302900 (3).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487413432_IMG_9472_frame_00043.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_9470_frame_00002.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK702647605810_BRBX_18m5d_432.0_01-08-2025_11-53-08_3_frame_08521.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk322936202797_IMG_9200.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105420_IMG_9465_frame_00072.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK162699407454_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-04-59_1_frame_000052 (5).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk341546640196_IMG_9205.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475503654_IMG_9494_frame_00116.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318211387_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-36-56_4_frame_000076.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK322917414290_IMG_9471_frame_00020.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511383_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-39-02_5_frame_000080.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9467_frame_00276.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9467_frame_00303.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK356379400182_IMG_9489_frame_00013.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_31-08-2025_09-39-09_2_UK743318111561_IMG_9497_frame_00000.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9479_frame_00052 - Copy.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111421_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-35-46_1_frame_000144 (5).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487513370_IMG_9464_frame_00011.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK162699407454_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-04-59_1_frame_000052 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK282668404422_IMG_30-08-2025_10-31-28_1_UK282668404422_IMG_9501_frame_00056.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9479_frame_00054.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk341282203271_IMG_9189.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_31-08-2025_09-40-34_1_UK743318311549_IMG_9467_frame_00028.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk324191701868_IMG_9142.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487713421_IMG_9499_frame_00090.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561 (1).jpg. Returning black image.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 141s 4s/step - loss: 0.2821 - mean_absolute_error: 0.3765 - val_loss: 0.4580 - val_mean_absolute_error: 0.4922
# Epoch 34/100
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105420_IMG_31-08-2025_09-26-02_2_UK323282105420_IMG_9484_frame_00000.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487213416_IMG_30-08-2025_10-22-20_1_UK160487213416_IMG_9491_frame_00005.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_9496_frame_00178.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_9496_frame_00107.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk342693526865_IMG_9195.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK321708507862_IMG_9477_frame_00114.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk324191601895.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK324431306229_IMG_31-08-2025_09-27-15_3_UK324431306229_IMG_9485_frame_00036.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475303645_IMG_9475_frame_00043.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk324191701868_IMG_9143.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105420_IMG_9465_frame_00070.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK702647605810_BRBX_18m5d_432.0_01-08-2025_11-53-08_5_frame_08677.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk166530105096.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_31-08-2025_09-40-53_1_UK743318311549_IMG_9479_frame_00028.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_9496_frame_00178.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK322917414290_IMG_9471_frame_00018.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487413432_IMG_9482_frame_00293.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487513370_IMG_30-08-2025_10-28-13_1_UK160487513370_IMG_9464_frame_00238.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_9496_frame_00147.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK324431306229_IMG_9485_frame_00161.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK356379400182_IMG_9489_frame_00010.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK341118503079_IMG_31-08-2025_09-29-06_1_UK341118503079_IMG_9483_frame_00008.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_9496_frame_00077.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK742081305449_IMG_31-08-2025_09-36-17_5_UK742081305449_IMG_9502_frame_00124.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK700626703750_IMG_9167.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk740047104361 (2).jpg. Returning black image.
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 3:03 5s/step - loss: 0.0961 - mean_absolute_error: 0.2326Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK745163114285_IMG_31-08-2025_09-42-29_2_UK745163114285_IMG_9503_frame_00000.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk745163414120.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk322936202797_IMG_9198.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK700626703750_IMG_9166.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK148708205489_AAX_15_583.0_07-11-2025_10-53-32_733.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk305901604011_IMG_9161.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK322963103963_IMG_31-08-2025_09-22-31_1_UK322963103963_IMG_9505_frame_00092.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487213416_IMG_9491_frame_00005.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_9496_frame_00077.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511383-2_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-38-01_1_frame_000028.jpg. Returning black image.
# ...
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk323638302900.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK324431306229_IMG_31-08-2025_09-27-15_3_UK324431306229_IMG_9485_frame_00036.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK148708105404_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_12-53-43_5_frame_000128.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487413432_IMG_9472_frame_00043.jpg. Returning black image.
# 31/44 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/stepWarning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475503654_IMG_9494_frame_00209.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511383_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-39-02_5_frame_000080.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK162699407454_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-04-59_1_frame_000052 (5).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk304246602416 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_31-08-2025_09-41-18_3_UK743318511537_IMG_9470_frame_00028.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk361610701400.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk160487313081_IMG_9185.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk342693526865_IMG_9195.jpg. Returning black image.
# 32/44 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/stepWarning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK322917414290_IMG_9471_frame_00019.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475303645_IMG_9475_frame_00043.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105406_IMG_9474_frame_00213.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK162699407454_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-04-59_1_frame_000052 (3).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105420_IMG_31-08-2025_09-25-15_1_UK323282105420_IMG_9465_frame_00056.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105406_IMG_9474_frame_00212.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_31-08-2025_09-40-34_1_UK743318311549_IMG_9467_frame_00028.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487413432_IMG_9482_frame_00293.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk345484602439.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_9496_frame_00107.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9467_frame_00276.jpg. Returning black image.
# 33/44 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/stepWarning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK356379400182_IMG_31-08-2025_09-34-17_1_UK356379400182_IMG_9489_frame_00028.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK322917414290_IMG_30-08-2025_10-33-22_1_UK322917414290_IMG_9471_frame_00020.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487713421_IMG_9499_frame_00147.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487213416_IMG_30-08-2025_10-22-58_1_UK160487213416_IMG_9492_frame_00020.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111393_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-35-00_1_frame_000024 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK165293605896_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-05-23_1_frame_000080.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK341282603275_IMG_9154.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK742081305449_IMG_9502_frame_00270.jpg. Returning black image.
# 34/44 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/stepWarning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK742081305449_IMG_31-08-2025_09-36-17_1_UK742081305449_IMG_9502_frame_00028.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK342693126826-3_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-31-58_1_frame_000176 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_9470_frame_00002.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK702647105728_BRBX_18m10d_488.5_01-08-2025_11-50-04_1_frame_06780.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9467_frame_00293.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_31-08-2025_09-39-09_2_UK743318111561_IMG_9497_frame_00000.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK303777401896_.jpg. Returning black image.
# 35/44 ━━━━━━━━━━━━━━━━━━━━ 23s 3s/stepWarning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475503654_IMG_9494_frame_00099.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487413432_IMG_9472_frame_00041.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/UK165879603778_IMG_9170 (3).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318211387-2_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-36-21_1_frame_000100 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk324431406083.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111421_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-35-46_1_frame_000144 (4).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511390_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-39-42_5_frame_000092 (3).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk160487313081_IMG_9187.jpg. Returning black image.
# 36/44 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/stepWarning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK322963103963_IMG_31-08-2025_09-21-18_3_UK322963103963_IMG_9487_frame_00336.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK321708507862_IMG_9477_frame_00111.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK745163114285_IMG_31-08-2025_09-42-29_2_UK745163114285_IMG_9503_frame_00000.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511383-2_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-38-01_1_frame_000028.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487213416_IMG_9468_frame_00078.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511383-3_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-38-37_1_frame_000192 (2).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk305901104013.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_9479_frame_00053 - Copy.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_31-08-2025_09-41-03_1_UK743318511537_IMG_9469_frame_00020.jpg. Returning black image.
# 37/44 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/stepWarning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_9470_frame_00000.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_9496_frame_00147.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475303645_IMG_9475_frame_00043.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK282668404422_IMG_9501_frame_00121.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318111561_IMG_31-08-2025_09-39-09_1_UK743318111561_IMG_9497_frame_00073.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_31-08-2025_09-40-53_1_UK743318311549_IMG_9479_frame_00028.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK282668404422_IMG_30-08-2025_10-31-28_1_UK282668404422_IMG_9501_frame_00056.jpg. Returning black image.
# 38/44 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/stepWarning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487413180_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_12-59-33_1_frame_000048.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk160487213409.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK162699407454_UNKNOWN_BREED_UNKNOWN_AGE_0.0_20-08-2025_13-04-59_1_frame_000052.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk222254101226_IMG_9147.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk341546640196_IMG_9204.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475303645_IMG_9475_frame_00042.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105420_IMG_9465_frame_00072.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK356379400182_IMG_9489_frame_00012.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk324191701868_IMG_9143.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_31-08-2025_09-40-44_1_UK743318311549_IMG_9478_frame_00028.jpg. Returning black image.
# 39/44 ━━━━━━━━━━━━━━━━━━━━ 13s 3s/stepWarning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318311549_IMG_31-08-2025_09-40-44_1_UK743318311549_IMG_9478_frame_00028.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/top_view_images/uk745163514310_IMG_9192.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK742081305449_IMG_9502_frame_00269.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743475503654_IMG_31-08-2025_09-42-15_5_UK743475503654_IMG_9494_frame_00208.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK160487113317_IMG_30-08-2025_10-21-43_2_UK160487113317_IMG_9463_frame_00020 (5).jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK323282105420_IMG_9484_frame_00001.jpg. Returning black image.
# Warning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK743318511537_IMG_31-08-2025_09-41-18_3_UK743318511537_IMG_9470_frame_00028.jpg. Returning black image.
# 40/44 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/stepWarning: Could not load image from /content/drive/MyDrive/dataset/side_view_images/UK742081305449_IMG_9502_frame_00270.jpg. Returning black image.
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 112s 3s/step
#
# --- TOP 20 WORST PREDICTIONS ---
#                                     side_view_filename  weight  \
# 299  UK305901404002_UNKNOWN_BREED_UNKNOWN_AGE_0.0_2...   721.0
# 655                                                NaN   346.5
# 643                                                NaN   386.5
# 657                                                NaN   346.5
# 616                                                NaN   390.0
# 260  UK164985204688_HE_9m18d_414.5_01-08-2025_12-11...   414.5
# 656                                                NaN   346.5
# 422            UK323282105406_IMG_9474_frame_00212.jpg   629.5
# 340  UK328761101293-4_UNKNOWN_BREED_UNKNOWN_AGE_0.0...   685.5
# 605                                                NaN   675.5
# 589  UK743318211394-2_UNKNOWN_BREED_UNKNOWN_AGE_0.0...   733.5
# 658                                                NaN   346.5
# 76   UK164985204688_HE_9m18d_414.5_01-08-2025_12-11...   414.5
# 613                                                NaN   759.5
# 642                                                NaN   386.5
# 318  UK305981630351_AAX_9m19d_374.5_01-08-2025_11-4...   374.5
# 154  UK200890300101_UNKNOWN_BREED_UNKNOWN_AGE_0.0_2...   406.0
# 617                                                NaN   390.0
# 560  UK342693126826_UNKNOWN_BREED_UNKNOWN_AGE_0.0_2...   714.0
# 568  UK702647605810_BRBX_18m5d_432.0_01-08-2025_11-...   432.0
#
#      predicted_weight_kg    error_kg
# 299           366.941498 -354.058502
# 655           636.735229  290.235229
# 643           654.203430  267.703430
# 657           614.069946  267.569946
# 616           656.166260  266.166260
# 260           680.468506  265.968506
# 656           610.737061  264.237061
# 422           366.941498 -262.558502
# 340           426.937744 -258.562256
# 605           417.058685 -258.441315
# 589           476.438080 -257.061920
# 658           602.853210  256.353210
# 76            663.383789  248.883789
# 613           512.938965 -246.561035
# 642           627.169617  240.669617
# 318           614.549133  240.049133
# 154           643.804138  237.804138
# 617           625.006409  235.006409
# 560           480.383362 -233.616638
# 568           658.007324  226.007324
# ---------------------------------
